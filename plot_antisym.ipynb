# %%
# %matplotlib inline
#HW03
#Matthew Espanol
#Partner: Matthew Del Rosario
from numpy import sin
from math import pi
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

def psi(x1,x2, n1=1,n2=2, a=1.0):
    psi= 2./a*(sin((n1*pi*x1)/a)*sin((n2*pi*x2)/a)-sin((n1*pi*x2)/a)*sin((n2*pi*x1)/a))
    return psi

def prob_density(p):
    density=(p**2)
    return density

def antisym(x1,x2, n1=1,n2=2, a=1.0):
    return psi(x1,x2, n1=1,n2=2, a=1.0) ,prob_density(psi(x1,x2, n1=1,n2=2, a=1.0))
    #x=psi(x1,x2, n1=1,n2=2, a=1.0)
    #y=prob_density(psi(x1,x2, n1=1,n2=2, a=1.0))

    #return x, y

print antisym(1.,2.)


fig=plt.figure()
ax= fig.add_subplot(111, projection='3d')
x= y = np.linspace(-1,1,10)
xv, yv= np.meshgrid(x, y)
z= antisym(xv,yv)
ax.plot_wireframe(xv, yv, z, rstride=4, cstride=4, linewidth=1)
#ax.plot_surface(xv,yv, z, rstride = 1, cstride = 1, cmap=cm.coolwarm, linewidth=0)
plt.show()
# Out:
# (-2.3996156522589722e-31, 5.7581552785662525e-62)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3d2c9d6a5bf4> in <module>()
#      33 xv, yv= np.meshgrid(x, y)
#      34 z= antisym(xv,yv)
# ---> 35 ax.plot_wireframe(xv, yv, z, rstride=4, cstride=4, linewidth=1)
#      36 #ax.plot_surface(xv,yv, z, rstride = 1, cstride = 1, cmap=cm.coolwarm, linewidth=0)
#      37 plt.show()
#
# /Users/MattEspanol/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.pyc in plot_wireframe(self, X, Y, Z, *args, **kwargs)
#    1738         # FIXME: Support masked arrays
#    1739         X, Y, Z = np.broadcast_arrays(X, Y, Z)
# -> 1740         rows, cols = Z.shape
#    1741
#    1742         # We want two sets of lines, one running along the "rows" of
#
# ValueError: too many values to unpack
